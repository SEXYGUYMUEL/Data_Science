# %% [markdown]
# # Test #2
#
# *필요한 최소한의 모듈은 모두 import 했습니다. 추가로 필요한 모듈이 있다면 임의로 추가하셔도 됩니다.*
#
# 만약 모듈이 설치되어 있지 않다면
# !pip install
# 을 사용하여 설치해 주세요

# %%
## 사용할 데이터를 import 합니다.

import numpy as np
import pandas as pd
import os
import matplotlib.pyplot as plt
from sklearn.datasets import make_blobs
from sklearn.metrics import silhouette_score
from sklearn.cluster import KMeans
from sklearn.cluster import DBSCAN
from sklearn.model_selection import GridSearchCV
from sklearn.model_selection import RandomizedSearchCV
from sklearn.pipeline import Pipeline
from sklearn.linear_model import LogisticRegression



X, y = make_blobs(n_samples=2000, centers=6, random_state=11)
plt.scatter(X[:, 0], X[:, 1], marker='o', c=y, s=2)
plt.xlabel("$X_1$")
plt.ylabel("$X_2$")
plt.show()

# %% [markdown]
# ** 모든 random_state = 11 로 통일합니다. **

# %% [markdown]
# #1 K-Means 알고리즘을 이용해 군집을 수행하세요
#
# 1. 실루엣 점수를 그래프를 통해 확인하고, 최적의 k값을 찾으세요
# 2. 최적의 k값에 해당하는 이너셔를 출력하세요
# 3. 군집을 완료한 것을 그래프로 출력하세요

# %% [markdown]
# k_means_per_k=[KMeans(n_clusters=k,random_state=11).fit(X)
#               for k in range(1,10)]

# %%
k_means_per_k=[KMeans(n_clusters=k,random_state=11).fit(X) for k in range(1,9)]

# %%
silhouette_scores=[silhouette_score(X,model.labels_)
                  for model in kmeans_per_k[1:]]

# %%
plt.figure(figsize=(8, 3))
plt.plot(range(1, 9), silhouette_scores)
plt.xlabel("$k$", fontsize=14)
plt.ylabel("Silhouette score", fontsize=14)
#save_fig("silhouette_score_vs_k_plot")
plt.show()

# %%
silhouette_scores
# Out:
# [0.42307028103970284,
#  0.5389688712790043,
#  0.6278315202246276,
#  0.747706353981014,
#  0.749744026915681,
#  0.6945877844129634,
#  0.6162647644569496,
#  0.5555609480309174]

# %%
# 최적의 k는 5일때 0.749744026915681로 실루엣값이 가장크다

# %%
# 이너셔출력
kmeans=KMeans(n_clusters=5)
kmeans.fit(X)
kmeans.inertia_
# Out:
# 8015.51851046798

# %%
y_pred=kmeans.predict(X)

# %%
plt.scatter(X[:, 0], X[:, 1], marker='o', c=y_pred,s=5)

# %% [markdown]
# #2 DBSCAN 알고리즘을 이용해 군집을 수행하세요
#
# 1. 군집을 완료한 것을 그래프로 출력하세요 (가능한 만큼 최대한 K-Means와 비슷하게 해주시면 됩니다. 채점 기준이 빡빡하지 않으니 똑같이 하려고 너무 집착하지 않으셔도 됩니다)

# %%
dbscan=DBSCAN(eps=1,min_samples=3)
dbscan.fit(X)
plt.scatter(X[:, 0], X[:, 1], marker='o', c=dbscan.labels_,s=5)

# %% [markdown]
# #3 해당 데이터셋을 군집하기에 더 적절한 알고리즘은 무엇인지 적고, 그 이유를 설명하세요.

# %%
# 산점도로 데이터 분포를 확인해볼시 비교적 이상치 데이터가 적게 식별되며, 특별한 기하학적인 특징을 가진 데이터라곤 생각되지않는다.
#또한 적절한 hyper-parameter설정이 번거로운 DBSCAN보다는 K-means 알고리즘이 더 적절하다고 생각한다.

# %% [markdown]
# #4 K-means 와 DBSCAN의 차이점에 대해 설명하세요.

# %%
# DBSCan(밀도기반)은 '유사한 데이터는 서로 근접하게 분포할것이다'라는 가정을 기반으로한다. Kmeans와 다르게 군집수를 설정할 필요가없이 자동적으로 최적의 군집수를 찾아나간다. 이상치에 대해 덜 민감하다. 노이즈개념으로 이상치 검출가능
# Kmeans(중심기반)는 '유사한 데이터는 중심점을 기반으로 분포할것'이라는 가정을 기반으로하며, 최적의 군집의 개수를 미리결정해야하며, 초기 중심점에 따라 결과가 달라진다. 또한 이상치에 민감하다.

# %% [markdown]
# #5 자신의 교과목 내용의 이해 정도를 표시해주세요(1-10 까지 숫자중,소수점 아래 한자리까지로 표시)
# (특별히 이해하기 어려운 부분이 있었다면 추가로 적어주세요)

# %%
# 9점 다양한 머신러닝에 대한 워크플로우와,개념은 이해하고있으나 실제 코드 구현이 아직은 미숙해 코딩이 조금 오래걸리는편인거같다.

# %% [markdown]
# #6 과제수행에 도움이 된 학우들의 이름과 사유(좋은 질문, 좋은 응답, 정보제공등)를 학생 수 제한 없이 적어주세요

# %%
# 박성찬 학우(좋은 질문,좋은 응답,정보제공), 김민식학우(좋은 응답), 김인웅학우(좋은응답),박찬영학우(정보제공), 남동수(정보제공)
